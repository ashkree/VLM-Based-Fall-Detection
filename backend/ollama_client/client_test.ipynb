# %%
import time
import os

# %%
from OllamaClient import OllamaClient

oc = OllamaClient(
    system_prompt="""
You are **FallDetect-AI**, a specialized vision model for fall detection in video surveillance.

**Your Task:**
Analyze individual frames from video sequences to detect falls and fall-related events.

**What to Detect:**
1. **FALL** - Active falling or post-fall state:
   - Rapid vertical descent or body collapse
   - Person lying on ground/floor
   - Impact or sudden loss of vertical orientation
   
2. **POSSIBLE_FALL** - Ambiguous or pre-fall indicators:
   - Significant loss of balance or stumbling
   - Unusual body angles suggesting instability
   - Unclear due to occlusion or image quality
   
3. **NO_FALL** - Normal activities:
   - Walking, standing, sitting, bending
   - Controlled movements (reaching, crouching)
   - No person in frame

**Temporal Awareness:**
When provided with previous frame analysis, use it to understand motion and state transitions.

**Output Format:**
Always respond in JSON:
{
  "classification": "FALL" | "POSSIBLE_FALL" | "NO_FALL",
  "confidence": 0.0-1.0,
  "reasoning": "Brief description of visual evidence"
}

**Special Cases:**
- No person visible → classification: "NO_FALL", confidence: 0.0, reasoning: "no person detected"
- Uncertain → classification: "POSSIBLE_FALL" with explanation

Be precise, consistent, and focus on safety-critical indicators.
"""
)

# %%
oc.health_check()
# Out:
# ✓ Ollama server is running
# True

# %%
oc.health_check()
# Out:
# Checking for model: qwen2.5vl:7b
# ✓ Model 'qwen2.5vl:7b' is available
# True

# %%
import os

path = "test_files/fall-01-cam0-rgb"

files = sorted([f for f in os.listdir(path)
         if os.path.isfile(os.path.join(path, f))])

# %%
frames = [f"{path}/{name}" for name in files]

print(frames)
# Out:
# ['test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-001.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-002.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-003.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-004.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-005.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-006.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-007.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-008.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-009.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-010.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-011.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-012.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-013.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-014.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-015.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-016.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-017.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-018.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-019.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-020.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-021.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-022.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-023.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-024.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-025.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-026.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-027.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-028.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-029.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-030.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-031.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-032.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-033.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-034.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-035.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-036.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-037.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-038.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-039.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-040.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-041.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-042.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-043.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-044.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-045.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-046.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-047.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-048.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-049.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-050.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-051.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-052.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-053.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-054.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-055.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-056.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-057.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-058.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-059.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-060.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-061.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-062.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-063.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-064.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-065.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-066.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-067.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-068.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-069.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-070.png', 'test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-071.png', 'test_files/fall-01-cam ...

# %%
oc.analyze_frame_sequence(frames)
# Out:
# processing batch 0
# processing test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-001.png
# processing test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-002.png
# processing test_files/fall-01-cam0-rgb/fall-01-cam0-rgb-003.png
